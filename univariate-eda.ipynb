# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("/kaggle/input/datasets/aliaamiri/titanic-passengers-and-crew-complete-list/titanic.csv")

# %%
df.head()
# Out:
#                              name  gender   age class embarked        country  \
# 0             Abbing, Mr. Anthony    male  42.0   3rd        S  United States
# 1       Abbott, Mr. Eugene Joseph    male  13.0   3rd        S  United States
# 2     Abbott, Mr. Rossmore Edward    male  16.0   3rd        S  United States
# 3  Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S        England
# 4     Abelseth, Miss. Karen Marie  female  16.0   3rd        S         Norway
#
#    ticketno   fare  sibsp  parch survived
# 0    5547.0   7.11    0.0    0.0       no
# 1    2673.0  20.05    0.0    2.0       no
# 2    2673.0  20.05    1.0    1.0       no
# 3    2673.0  20.05    1.0    1.0      yes
# 4  348125.0   7.13    0.0    0.0      yes

# %%
df.shape
# Out:
# (2207, 11)

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# **a) countplot**

# %%
sns.countplot(df['survived'],axis)
# Out:
# <Axes: xlabel='count', ylabel='survived'>

# %%
df['survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='survived'>

# %%
sns.countplot(df['embarked'])
df['embarked'].value_counts()
# Out:
# embarked
# S    1616
# C     271
# B     197
# Q     123
# Name: count, dtype: int64

# %% [markdown]
# **b) PIECHART**

# %%
df['survived'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['embarked'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# **a) HISTOGRAM**

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['age'],color='yellow',edgecolor='black')
# Out:
# (array([ 74.,  49., 453., 555., 511., 275., 163.,  79.,  39.,   7.]),
#  array([ 0.16666667,  7.55      , 14.93333333, 22.31666667, 29.7       ,
#         37.08333333, 44.46666667, 51.85      , 59.23333333, 66.61666667,
#         74.        ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **b) DISTPLOT**

# %%
sns.distplot(df['age'])
# Out:
# /tmp/ipykernel_55/3234920688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# **BOXPLOT**

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
df['age'].min()
# Out:
# 0.1666666667

# %%
df['age'].max()
# Out:
# 74.0

# %%
df['age'].mean()
# Out:
# np.float64(30.444444444444397)

# %%
df['age'].median()
# Out:
# 29.0
