# %%
import pandas as pd

# %% [markdown]
# #Importing Data

# %%
df=pd.read_csv("/kaggle/input/datasets/divjotbedi/top-rated-10000-movies/df_movie.csv")

# %% [markdown]
# #How Big Data is?

# %%
df.shape
# Out:
# (10000, 8)

# %% [markdown]
# info about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    10000 non-null  int64
#  1   id            10000 non-null  int64
#  2   title         10000 non-null  object
#  3   release_date  9997 non-null   object
#  4   popularity    10000 non-null  float64
#  5   vote_average  10000 non-null  float64
#  6   vote_count    10000 non-null  int64
#  7   overview      9998 non-null   object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 625.1+ KB

# %% [markdown]
# How Data looks like?

# %%
df.head(10)
# Out:
#    Unnamed: 0       id                        title release_date  popularity  \
# 0           0      278     The Shawshank Redemption   1994-09-23     42.1605
# 1           1      238                The Godfather   1972-03-14     36.5278
# 2           2      240        The Godfather Part II   1974-12-20     25.5386
# 3           3      424             Schindler's List   1993-12-15     23.5837
# 4           4      389                 12 Angry Men   1957-04-10     19.3006
# 5           5  1181678        ¿Quieres ser mi hijo?   2023-09-21      7.9646
# 6           6      129                Spirited Away   2001-07-20     28.6520
# 7           7      155              The Dark Knight   2008-07-16     41.0006
# 8           8    19404  Dilwale Dulhania Le Jayenge   1995-10-20     11.6598
# 9           9      497               The Green Mile   1999-12-10     26.0735
#
#    vote_average  vote_count                                           overview
# ...

# %% [markdown]
# #NULL values count

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# id              0
# title           0
# release_date    3
# popularity      0
# vote_average    0
# vote_count      0
# overview        2
# dtype: int64

# %% [markdown]
# #how data looks mathematically?

# %%
df.describe()
# Out:
#         Unnamed: 0            id    popularity  vote_average    vote_count
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    4999.50000  2.270300e+05      4.460590      6.736070   2091.774400
# std     2886.89568  3.021682e+05      9.142035      0.654126   3342.697826
# min        0.00000  2.000000e+00      0.005800      5.471000    300.000000
# 25%     2499.75000  1.035250e+04      2.029100      6.203750    476.000000
# 50%     4999.50000  4.162000e+04      2.934800      6.700000    868.000000
# 75%     7499.25000  4.064295e+05      4.669550      7.200000   2096.000000
# max     9999.00000  1.472638e+06    304.572000      8.717000  39214.000000

# %% [markdown]
# #Duplicated items

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #correlation

# %%
# Out:
# <bound method DataFrame.corr of       Unnamed: 0       id                     title release_date  popularity  \
# 0              0      278  The Shawshank Redemption   1994-09-23     42.1605
# 1              1      238             The Godfather   1972-03-14     36.5278
# 2              2      240     The Godfather Part II   1974-12-20     25.5386
# 3              3      424          Schindler's List   1993-12-15     23.5837
# 4              4      389              12 Angry Men   1957-04-10     19.3006
# ...          ...      ...                       ...          ...         ...
# 9995        9995     9796                  Turistas   2006-12-01      2.7055
# 9996        9996   253310                 Premature   2014-07-02      2.7309
# 9997        9997    87368                  17 Girls   2011-06-13      0.5833
# 9998        9998  1063422                The Strays   2023-02-17      2.0145
# 9999        9999    75198            Welcome Aboard   2011-10-05      1.2395
#
# ...
