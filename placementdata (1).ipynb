# %%
import numpy as np

# %%
a=np.array(4)

# %%
a
# Out:
# array(4)

# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/datasets/jtrotman/formula-1-race-data/circuits.csv")

# %%
df.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
df.shape
# Out:
# (78, 9)

# %%
df.head(78)
# Out:
#     circuitId   circuitRef                            name      location  \
# 0           1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1           2       sepang    Sepang International Circuit  Kuala Lumpur
# 2           3      bahrain   Bahrain International Circuit        Sakhir
# 3           4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4           5     istanbul                   Istanbul Park      Istanbul
# ..        ...          ...                             ...           ...
# 73         77       jeddah         Jeddah Corniche Circuit        Jeddah
# 74         78       losail    Losail International Circuit     Al Daayen
# 75         79        miami   Miami International Autodrome         Miami
# 76         80        vegas  Las Vegas Strip Street Circuit     Las Vegas
# 77         81      madring                         Madring        Madrid
#
#           country       lat        lng  alt  \
# 0       Australia -37.84970  144.96800   10
# ...

# %%
df1 = pd.read_csv("/kaggle/input/datasets/sahilislam007/college-student-placement-factors-dataset/college_student_placement_dataset.csv")

# %%
df1.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB

# %%
df1 = df1.iloc[:, [ 1, 3, 9]]

# %%
df1.head()
# Out:
#     IQ  CGPA Placement
# 0  107  6.28        No
# 1   97  5.37        No
# 2  109  5.83        No
# 3  122  5.75        No
# 4   96  7.69        No

# %%
df1.loc[:, "Placement"] = (
    df1["Placement"]
    .str.strip()
    .str.lower()
    .map({"yes": 1, "no": 0})
    .astype(int)
)

# %%
print(df1["Placement"].unique())
print(df1["Placement"].dtype)
# Out:
# [0 1]
# object

# %%
df1.head(20)
# Out:
#      IQ   CGPA Placement
# 0   107   6.28         0
# 1    97   5.37         0
# 2   109   5.83         0
# 3   122   5.75         0
# 4    96   7.69         0
# 5    96   5.32         0
# 6   123   6.58         1
# 7   111   8.76         1
# 8    92   6.33         0
# 9   108   8.60         0
# 10   93   8.90         0
# 11   93   6.51         0
# 12  103   9.01         0
# 13   71   8.40         0
# 14   74   7.31         0
# 15   91   5.80         0
# 16   84   7.54         0
# 17  104  10.01         0
# 18   86   8.15         1
# 19   78   5.56         0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df1['IQ'],df1['CGPA'])

# %%
plt.scatter(
    df_sample['CGPA'],
    df_sample['IQ'],
    c=df_sample['Placement']
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_55/942182653.py in <cell line: 0>()
#       1 plt.scatter(
# ----> 2     df_sample['CGPA'],
#       3     df_sample['IQ'],
#       4     c=df_sample['Placement']
#       5 )
#
# NameError: name 'df_sample' is not defined

# %%
X=df1.iloc[:,0:2]

# %%
X
# Out:
#        IQ  CGPA
# 0     107  6.28
# 1      97  5.37
# 2     109  5.83
# 3     122  5.75
# 4      96  7.69
# ...   ...   ...
# 9995  119  8.29
# 9996   70  9.34
# 9997   89  6.25
# 9998  107  8.92
# 9999  109  9.77
#
# [10000 rows x 2 columns]

# %%
Y=df1.iloc[:,-1]

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    1
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Placement, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1)

# %%
X_train
# Out:
#        IQ  CGPA
# 9321   93  8.38
# 8242   97  8.20
# 5026   84  5.13
# 3368  106  6.60
# 7212   80  9.96
# ...   ...   ...
# 4087  101  8.05
# 3087  118  8.74
# 2     109  5.83
# 9816  101  7.87
# 9525   87  6.42
#
# [9000 rows x 2 columns]

# %%
X_test
# Out:
#        IQ  CGPA
# 433   110  6.26
# 5614   92  5.29
# 4883  107  5.28
# 3029  100  8.58
# 1442  102  9.40
# ...   ...   ...
# 6097  101  8.62
# 2701  116  7.37
# 9536   88  8.01
# 872    79  7.72
# 686    96  4.70
#
# [1000 rows x 2 columns]

# %%
Y_train
# Out:
# 9321    0
# 8242    1
# 5026    0
# 3368    0
# 7212    0
#        ..
# 4087    0
# 3087    0
# 2       0
# 9816    0
# 9525    0
# Name: Placement, Length: 9000, dtype: object

# %%
Y_test
# Out:
# 433     0
# 5614    0
# 4883    0
# 3029    0
# 1442    0
#        ..
# 6097    0
# 2701    1
# 9536    1
# 872     0
# 686     0
# Name: Placement, Length: 1000, dtype: object

# %% [markdown]
# #model

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.42641886,  0.58319071],
#        [-0.16041046,  0.46062095],
#        [-1.02493778, -1.62987445],
#        ...,
#        [ 0.63761476, -1.15321426],
#        [ 0.10559795,  0.23590972],
#        [-0.82543147, -0.75145781]])

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.70411686, -0.86040871],
#        [-0.49292096, -1.52092355],
#        [ 0.50461056, -1.52773298],
#        ...,
#        [-0.75892937,  0.33124176],
#        [-1.35744828,  0.13376825],
#        [-0.22691256, -1.92267999]])

# %% [markdown]
# **#MODEL TRAINING**

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_55/3364754999.py in <cell line: 0>()
# ----> 1 clf.fit(X_train,Y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1229             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1230         )
# -> 1231         check_classification_targets(y)
#    1232         self.classes_ = np.unique(y)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     220         "multilabel-sequences",
# ...

# %%
print(Y_train.unique())
print(Y_train.dtype)
# Out:
# [0 1]
# object

# %%
df1["Placement"] = df1["Placement"].astype(int)

# %%
print(df1["Placement"].dtype)
# Out:
# int64

# %%
clf.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_55/3364754999.py in <cell line: 0>()
# ----> 1 clf.fit(X_train,Y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1229             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1230         )
# -> 1231         check_classification_targets(y)
#    1232         self.classes_ = np.unique(y)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     220         "multilabel-sequences",
# ...

# %%
print(Y.unique())
print(Y.dtype)
print(type(Y.iloc[0]))
# Out:
# [0 1]
# object
# <class 'int'>

# %%
df1["Placement"] = pd.to_numeric(df1["Placement"], errors="coerce")
df1 = df1.dropna(subset=["Placement"])
df1["Placement"] = df1["Placement"].astype(int)

# %%
print(df1["Placement"].dtype)
print(df1["Placement"].unique())
# Out:
# int64
# [0 1]

# %%
X = df1.drop("Placement", axis=1)
y = df1["Placement"]

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X.dtypes)
# Out:
# IQ        int64
# CGPA    float64
# dtype: object

# %%
clf.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(X_test)

# %%
Y_test
# Out:
# 9758    0
# 1399    0
# 9087    0
# 2209    0
# 6376    0
#        ..
# 1178    0
# 6633    0
# 8813    0
# 147     0
# 635     0
# Name: Placement, Length: 2000, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.8605

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train.values,Y_train.values,clf=clf,legend=2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
df_sample = df1.sample(200, random_state=42)

X_sample = df_sample[["IQ", "CGPA"]].values
y_sample = df_sample["Placement"].values

plot_decision_regions(X_sample, y_sample, clf=clf, legend=2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >
